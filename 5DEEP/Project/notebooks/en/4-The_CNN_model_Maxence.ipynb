# %% [markdown]
# ## School project - 5DEEP
# The following notebook has been created for a school project on audio classification. The subject and the questions are available in the appendix.
#
# The group members who participated in this project are:
# - BEZIN Théo
# - LAMINE AMIMI
# - LECOMTE Alexis
# - PAWLOWSKI Maxence
#
# ### Main index
# 1. Data analysis
# 2. Data preprocessing
# 3. Basic ANN model
# 4. **The CNN model (you are here)**
# 5. Testing our best model

# %% [markdown]
# # 4 - The CNN model
# Our previous model showed very poor performance on the Mel spectrogram. For this notebook, we will define a Convolutional Neural Network (CNN) that takes a three-dimensional array as input. The extra dimensions will allow the model to train better by extracting more features from the spectrograms.
#
# ### Index
# <ol type="A">
#   <li>Notebook initialization</li>
#   <li>Data preparation</li>
#   <li>Second model: Convolutional Neural Network (CNN)</li>
#   <li>Evaluating the model</li>
#   <li>Conclusion of the CNN model</li>
# </ol>

# %% [markdown]
# ## A - Notebook initialization
# ### A.1 - Imports

# %%
# OS and filesystem
import os
import sys
from pathlib import Path
from timeit import default_timer as timer
from datetime import timedelta

# Math
import numpy

# Data
from matplotlib import pyplot

# Model processing
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow import keras

# Console output
from colorama import Style

# Local files
sys.path.append(os.path.join(os.pardir, os.pardir))
import helpers

# %% [markdown]
# ### A.2 - Package initialization

# %%
pyplot.style.use("ggplot")  # Set the matplotlib style
keras.backend.set_image_data_format("channels_last")  # Define the last value of the model input shape as the color channel

# %% [markdown]
# ### A.3 - Constants

# %%
# Filesystem paths
PARENT_FOLDER = Path.cwd()
DATA_FOLDER = (PARENT_FOLDER / ".." / ".." / "data").resolve()
URBAN_DATASET_FOLDER = DATA_FOLDER / "UrbanSound8K"
MODELS_FOLDER = (PARENT_FOLDER / ".." / ".." / "models").resolve()
TEMP_FOLDER = (PARENT_FOLDER / ".." / ".." / "temp").resolve()

# Dataset
CLASSES = ["air_conditioner", "car_horn", "children_playing", "dog_bark", "drilling", "engine_idling", "gun_shot", "jackhammer", "siren", "street_music"]
N_MELS = 128

# Misc.
RANDOM_STATE = 2077

# %% [markdown]
# ### A.4 - Dataset loading

# %%
features_x = numpy.load(file=(str(DATA_FOLDER / "x-mel-spectrograms_13-02-23_14-44.npy")))
features_y = numpy.load(file=(str(DATA_FOLDER / "y-mel-spectrograms_13-02-23_14-44.npy")))

# %% [markdown]
# ## B - Data preparation
# ### B.1 - Label encoding
# We will use the same encoding method as for the ANN model, a one-hot encoding.

# %%
label_encoder = LabelEncoder()
features_y = keras.utils.to_categorical(y=label_encoder.fit_transform(features_y), num_classes=len(CLASSES))

# %% [markdown]
# ### B.2 - Dataset splitting

# %%
x_train, x_test, y_train, y_test = train_test_split(features_x, features_y, test_size=0.2, random_state=RANDOM_STATE)

print(f"{Style.BRIGHT}Train set >{Style.RESET_ALL} rows: (x={len(x_train)}, y={len(y_train)}) | shape: (x={x_train.shape}, y={y_train.shape})")
print(f"{Style.BRIGHT}Test set >{Style.RESET_ALL} rows: (x={len(x_test)}, y={len(y_test)}) | shape: (x={x_test.shape}, y={y_test.shape})")
# Out:
# Train set > rows: (x=6985, y=6985) | shape: (x=(6985, 128, 173), y=(6985, 10))
# Test set > rows: (x=1747, y=1747) | shape: (x=(1747, 128, 173), y=(1747, 10))

# %% [markdown]
# The input layer of the CNN model takes a 4+D tensor with the form $batchShape, (rows, cols, channels)$. We need to reshape our dataset to match the second part in parentheses.

# %%
num_columns = 173
num_channels = 1

x_train = x_train.reshape(x_train.shape[0], N_MELS, num_columns, num_channels)
x_test = x_test.reshape(x_test.shape[0], N_MELS, num_columns, num_channels)

# %% [markdown]
# ## C - Second model: Convolutional Neural Network (CNN)
# ### C.1 - Model architecture
# We will use the same model API as for the ANN, the [Sequential](https://keras.io/guides/sequential_model/) API.
#
# 1. The first three groups start with a [Conv2D](https://keras.io/api/layers/convolution_layers/convolution2d/) layer. It creates a convolution kernel that is convolved with the layer input to produce a tensor of outputs. The input shape of this layer is $batchShape, (rows, cols, channels)$ and the output shape is $batchShape, (newRows, newCols, filters)$. The next layer is a [MaxPooling2D](https://keras.io/api/layers/pooling_layers/max_pooling2d/) layer that down-samples the input along its spatial dimensions (height and width). The final layer of those groups is the [activation function](https://keras.io/api/layers/core_layers/activation/).
# 2. The fourth group begins with a [Flatten](https://keras.io/api/layers/reshaping_layers/flatten/) layer used, as the name suggests, to flatten the input. This group ends with the [Dropout](https://keras.io/api/layers/regularization_layers/dropout/) layer which "removes" input values by setting them to 0. This layer prevents over-fitting.
# 3. The last two groups are classic [Dense](https://keras.io/api/layers/core_layers/dense/) layers with a [softmax](https://keras.io/api/layers/activations/#softmax-function) activation function for the final output.
#
# ### C.2 - Model definition

# %%
# Model definition
model_cnn_chandelle = keras.models.Sequential(name="CNN_Chandelle", layers=[
    # First convolution block
    keras.layers.Conv2D(filters=64, kernel_size=(3, 3), input_shape=(N_MELS, num_columns, num_channels)),
    keras.layers.MaxPooling2D(pool_size=(2, 2)),
    keras.layers.Activation("relu"),

    # Second convolution block
    keras.layers.Conv2D(filters=64, kernel_size=(3, 3), padding="valid"),
    keras.layers.MaxPooling2D(pool_size=(2, 2)),
    keras.layers.Activation("relu"),

    # Flatten and dropout
    keras.layers.Flatten(),
    keras.layers.Dropout(rate=0.1),

    # First dense block
    keras.layers.Dense(64, activation="relu"),
    keras.layers.Dropout(rate=0.5),

    # Second dense block. Using softmax to reduce to output to 1
    keras.layers.Dense(len(CLASSES), activation="softmax")
])

# Model summary and plot
model_cnn_chandelle.summary()
keras.utils.plot_model(
    model_cnn_chandelle,
    show_shapes=True, show_dtype=True, show_layer_names=True, show_layer_activations=True,
    rankdir="TB", dpi=72,
    to_file=(TEMP_FOLDER / "model_cnn_chandelle.png")
)
# Out:
# Model: "CNN_Chandelle"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 171, 64)      640
#
#  max_pooling2d (MaxPooling2D  (None, 63, 85, 64)       0
#  )
#
#  activation (Activation)     (None, 63, 85, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 61, 83, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 41, 64)       0
#  2D)
#
#  activation_1 (Activation)   (None, 30, 41, 64)        0
#
#  flatten (Flatten)           (None, 78720)             0
#
#  dropout (Dropout)           (None, 78720)             0
#
#  dense (Dense)               (None, 64)                5038144
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 5,076,362
# Trainable params: 5,076,362
# Non-trainable params: 0
# _________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# ### C.3 - Model optimizer and loss function

# %%
adam_optimizer = keras.optimizers.Adam(learning_rate=0.001)
model_cnn_chandelle.compile(loss="categorical_crossentropy", optimizer=adam_optimizer, metrics=["accuracy"])

# %% [markdown]
# ### C.4 - Model callbacks

# %%
# Model checkpoint to save the model to the disk
ckpt_name_base = "2_model-cnn-chandelle-ckpt"

checkpoint_callback = keras.callbacks.ModelCheckpoint(
    filepath=str(MODELS_FOLDER / f"{ckpt_name_base}_e-{{epoch:02d}}_vloss-{{val_loss:.2f}}.hdf5"),
    monitor="val_loss",
    save_best_only=True,
    verbose=0
)

# %% [markdown]
# ### C.5 - Model training

# %%
batch_size = 128
epochs = 200

start_time = timer()
training_cnn_chandelle = model_cnn_chandelle.fit(x=x_train, y=y_train, validation_split=0.080, batch_size=batch_size, epochs=epochs, callbacks=[checkpoint_callback], verbose=1)
print(f"The training of the \"{model_cnn_chandelle.name}\" model took {timedelta(seconds=(timer() - start_time))}.")
# Out:
# Epoch 1/200
# 51/51 [==============================] - 14s 89ms/step - loss: 2.0120 - accuracy: 0.2988 - val_loss: 1.4712 - val_accuracy: 0.5206
# Epoch 2/200
# 51/51 [==============================] - 4s 78ms/step - loss: 1.4601 - accuracy: 0.4837 - val_loss: 1.2435 - val_accuracy: 0.5420
# Epoch 3/200
# 51/51 [==============================] - 4s 70ms/step - loss: 1.2473 - accuracy: 0.5668 - val_loss: 1.0445 - val_accuracy: 0.6422
# Epoch 4/200
# 51/51 [==============================] - 3s 68ms/step - loss: 1.0729 - accuracy: 0.6292 - val_loss: 0.8886 - val_accuracy: 0.6941
# Epoch 5/200
# 51/51 [==============================] - 4s 69ms/step - loss: 0.9116 - accuracy: 0.6864 - val_loss: 0.8641 - val_accuracy: 0.7174
# Epoch 6/200
# 51/51 [==============================] - 4s 69ms/step - loss: 0.8030 - accuracy: 0.7202 - val_loss: 0.7141 - val_accuracy: 0.7818
# Epoch 7/200
# 51/51 [==============================] - 4s 69ms/step - loss: 0.6775 - accuracy: 0.7614 - val_loss: 0.6685 - val_accuracy: 0.7871
# Epoch 8/200
# 51/51 [==============================] - 4s 70ms/step - loss: 0.6247 - accuracy: 0.7806 - val_loss: 0.6374 - val_accuracy: 0.7871
# Epoch 9/200
# 51/51 [==============================] - 3s 69ms/step - loss: 0.5401 - accuracy: 0.8131 - val_loss: 0.6409 - val_accuracy: 0.8032
# Epoch 10/200
# 51/51 [==============================] - 3s 69ms/step - loss: 0.4766 - accuracy: 0.8341 - val_loss: 0.6226 - val_accuracy: 0.8050
# Epoch 11/200
# 51/51 [==============================] - 3s 67ms/step - loss: 0.4281 - accuracy: 0.8445 - val_loss: 0.6342 - val_accuracy: 0.8104
# Epoch 12/200
# 51/51 [==============================] - 4s 69ms/step - loss: 0.4060 - accuracy: 0.8529 - val_loss: 0.6185 - val_accuracy: 0.8068
# Epoch 13/200
# 51/51 [==============================] - 3s 67ms/step - loss: 0.3672 - accuracy: 0.8620 - val_loss: 0.6366 - val_accuracy: 0.8229
# Epoch 14/200
# 51/51 [==============================] - 4s 69ms/step - loss: 0.3248 - accuracy: 0.8817 - val_loss: 0.6008 - val_accuracy: 0.8318
# Epoch 15/200
# 51/51 [==============================] - 3s 67ms/step - loss: 0.2951 - accuracy: 0.8909 - val_loss: 0.6517 - val_accuracy: 0.8426
# Epoch 16/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.2677 - accuracy: 0.9066 - val_loss: 0.6425 - val_accuracy: 0.8247
# Epoch 17/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.2744 - accuracy: 0.8937 - val_loss: 0.6587 - val_accuracy: 0.8372
# Epoch 18/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.2436 - accuracy: 0.9068 - val_loss: 0.6647 - val_accuracy: 0.8444
# Epoch 19/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.2375 - accuracy: 0.9121 - val_loss: 0.6821 - val_accuracy: 0.8479
# Epoch 20/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.2166 - accuracy: 0.9172 - val_loss: 0.6469 - val_accuracy: 0.8354
# Epoch 21/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.2046 - accuracy: 0.9195 - val_loss: 0.7179 - val_accuracy: 0.8336
# Epoch 22/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.1908 - accuracy: 0.9237 - val_loss: 0.6637 - val_accuracy: 0.8479
# Epoch 23/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.1898 - accuracy: 0.9273 - val_loss: 0.6945 - val_accuracy: 0.8318
# Epoch 24/200
# 51/51 [==============================] - 4s 71ms/step - loss: 0.1819 - accuracy: 0.9306 - val_loss: 0.6845 - val_accuracy: 0.8372
# Epoch 25/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.1655 - accuracy: 0.9365 - val_loss: 0.8061 - val_accuracy: 0.8408
# Epoch 26/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.1630 - accuracy: 0.9336 - val_loss: 0.7652 - val_accuracy: 0.8408
# Epoch 27/200
# 51/51 [==============================] - 3s 67ms/step - loss: 0.1632 - accuracy: 0.9351 - val_loss: 0.7948 - val_accuracy: 0.8247
# Epoch 28/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.1514 - accuracy: 0.9448 - val_loss: 0.7674 - val_accuracy: 0.8336
# Epoch 29/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.1436 - accuracy: 0.9416 - val_loss: 0.7013 - val_accuracy: 0.8479
# Epoch 30/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.1560 - accuracy: 0.9385 - val_loss: 0.7898 - val_accuracy: 0.8408
# Epoch 31/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.1429 - accuracy: 0.9420 - val_loss: 0.8165 - val_accuracy: 0.8515
# Epoch 32/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.1323 - accuracy: 0.9480 - val_loss: 0.7530 - val_accuracy: 0.8533
# Epoch 33/200
# 51/51 [==============================] - 3s 67ms/step - loss: 0.1349 - accuracy: 0.9482 - val_loss: 0.8292 - val_accuracy: 0.8283
# Epoch 34/200
# 51/51 [==============================] - 3s 67ms/step - loss: 0.1320 - accuracy: 0.9454 - val_loss: 0.8367 - val_accuracy: 0.8265
# Epoch 35/200
# 51/51 [==============================] - 3s 69ms/step - loss: 0.1239 - accuracy: 0.9485 - val_loss: 0.8762 - val_accuracy: 0.8336
# Epoch 36/200
# 51/51 [==============================] - 3s 67ms/step - loss: 0.1443 - accuracy: 0.9413 - val_loss: 0.7947 - val_accuracy: 0.8426
# Epoch 37/200
# 51/51 [==============================] - 3s 67ms/step - loss: 0.1272 - accuracy: 0.9497 - val_loss: 0.8740 - val_accuracy: 0.8444
# Epoch 38/200
# 51/51 [==============================] - 3s 67ms/step - loss: 0.1168 - accuracy: 0.9547 - val_loss: 0.9331 - val_accuracy: 0.8479
# Epoch 39/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.1213 - accuracy: 0.9505 - val_loss: 0.8848 - val_accuracy: 0.8462
# Epoch 40/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.1135 - accuracy: 0.9518 - val_loss: 0.8870 - val_accuracy: 0.8444
# Epoch 41/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.1178 - accuracy: 0.9502 - val_loss: 0.8643 - val_accuracy: 0.8372
# Epoch 42/200
# 51/51 [==============================] - 3s 67ms/step - loss: 0.1095 - accuracy: 0.9561 - val_loss: 0.9068 - val_accuracy: 0.8354
# Epoch 43/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.1010 - accuracy: 0.9599 - val_loss: 0.9719 - val_accuracy: 0.8301
# Epoch 44/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.1026 - accuracy: 0.9569 - val_loss: 0.9352 - val_accuracy: 0.8372
# Epoch 45/200
# 51/51 [==============================] - 3s 69ms/step - loss: 0.1033 - accuracy: 0.9567 - val_loss: 0.9974 - val_accuracy: 0.8479
# Epoch 46/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.1085 - accuracy: 0.9544 - val_loss: 0.9368 - val_accuracy: 0.8497
# Epoch 47/200
# 51/51 [==============================] - 3s 67ms/step - loss: 0.1064 - accuracy: 0.9560 - val_loss: 0.9131 - val_accuracy: 0.8587
# Epoch 48/200
# 51/51 [==============================] - 3s 67ms/step - loss: 0.1008 - accuracy: 0.9581 - val_loss: 0.9613 - val_accuracy: 0.8318
# Epoch 49/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.1015 - accuracy: 0.9577 - val_loss: 0.9776 - val_accuracy: 0.8444
# Epoch 50/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.0957 - accuracy: 0.9630 - val_loss: 1.0733 - val_accuracy: 0.8444
# Epoch 51/200
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0944 - accuracy: 0.9616 - val_loss: 1.0843 - val_accuracy: 0.8426
# Epoch 52/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.0940 - accuracy: 0.9597 - val_loss: 0.9616 - val_accuracy: 0.8408
# Epoch 53/200
# 51/51 [==============================] - 4s 70ms/step - loss: 0.0919 - accuracy: 0.9647 - val_loss: 0.9941 - val_accuracy: 0.8462
# Epoch 54/200
# 51/51 [==============================] - 4s 69ms/step - loss: 0.0889 - accuracy: 0.9630 - val_loss: 0.8861 - val_accuracy: 0.8354
# Epoch 55/200
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0863 - accuracy: 0.9642 - val_loss: 1.0114 - val_accuracy: 0.8408
# Epoch 56/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.0910 - accuracy: 0.9611 - val_loss: 1.1682 - val_accuracy: 0.8283
# Epoch 57/200
# 51/51 [==============================] - 3s 69ms/step - loss: 0.1013 - accuracy: 0.9581 - val_loss: 1.0019 - val_accuracy: 0.8551
# Epoch 58/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.0926 - accuracy: 0.9608 - val_loss: 1.0569 - val_accuracy: 0.8301
# Epoch 59/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.0892 - accuracy: 0.9625 - val_loss: 1.0191 - val_accuracy: 0.8444
# Epoch 60/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.0881 - accuracy: 0.9625 - val_loss: 1.0653 - val_accuracy: 0.8318
# Epoch 61/200
# 51/51 [==============================] - 4s 69ms/step - loss: 0.0992 - accuracy: 0.9567 - val_loss: 1.0028 - val_accuracy: 0.8426
# Epoch 62/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.0818 - accuracy: 0.9655 - val_loss: 1.0149 - val_accuracy: 0.8551
# Epoch 63/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.0947 - accuracy: 0.9625 - val_loss: 1.0146 - val_accuracy: 0.8569
# Epoch 64/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.0871 - accuracy: 0.9642 - val_loss: 1.0149 - val_accuracy: 0.8551
# Epoch 65/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.0988 - accuracy: 0.9585 - val_loss: 1.0258 - val_accuracy: 0.8390
# Epoch 66/200
# 51/51 [==============================] - 4s 69ms/step - loss: 0.0905 - accuracy: 0.9613 - val_loss: 0.9376 - val_accuracy: 0.8533
# Epoch 67/200
# 51/51 [==============================] - 4s 70ms/step - loss: 0.0858 - accuracy: 0.9630 - val_loss: 1.0542 - val_accuracy: 0.8497
# Epoch 68/200
# 51/51 [==============================] - 4s 69ms/step - loss: 0.0753 - accuracy: 0.9712 - val_loss: 1.0707 - val_accuracy: 0.8479
# Epoch 69/200
# 51/51 [==============================] - 3s 69ms/step - loss: 0.0801 - accuracy: 0.9664 - val_loss: 1.0424 - val_accuracy: 0.8479
# Epoch 70/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.0867 - accuracy: 0.9627 - val_loss: 1.1520 - val_accuracy: 0.8444
# Epoch 71/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.0968 - accuracy: 0.9611 - val_loss: 0.9839 - val_accuracy: 0.8479
# Epoch 72/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.0767 - accuracy: 0.9673 - val_loss: 1.0576 - val_accuracy: 0.8640
# Epoch 73/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.0778 - accuracy: 0.9678 - val_loss: 1.0568 - val_accuracy: 0.8336
# Epoch 74/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.0802 - accuracy: 0.9644 - val_loss: 1.0536 - val_accuracy: 0.8587
# Epoch 75/200
# 51/51 [==============================] - 3s 69ms/step - loss: 0.0744 - accuracy: 0.9690 - val_loss: 1.0974 - val_accuracy: 0.8515
# Epoch 76/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.0780 - accuracy: 0.9673 - val_loss: 1.2352 - val_accuracy: 0.8479
# Epoch 77/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.0808 - accuracy: 0.9675 - val_loss: 1.0906 - val_accuracy: 0.8444
# Epoch 78/200
# 51/51 [==============================] - 3s 69ms/step - loss: 0.0715 - accuracy: 0.9687 - val_loss: 1.1303 - val_accuracy: 0.8605
# Epoch 79/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.0799 - accuracy: 0.9686 - val_loss: 1.1033 - val_accuracy: 0.8569
# Epoch 80/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.0777 - accuracy: 0.9664 - val_loss: 1.2907 - val_accuracy: 0.8426
# Epoch 81/200
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0848 - accuracy: 0.9648 - val_loss: 1.1514 - val_accuracy: 0.8623
# Epoch 82/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.0779 - accuracy: 0.9697 - val_loss: 1.1590 - val_accuracy: 0.8426
# Epoch 83/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.0756 - accuracy: 0.9711 - val_loss: 1.1460 - val_accuracy: 0.8372
# Epoch 84/200
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0761 - accuracy: 0.9700 - val_loss: 1.1332 - val_accuracy: 0.8444
# Epoch 85/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.0823 - accuracy: 0.9655 - val_loss: 1.1338 - val_accuracy: 0.8444
# Epoch 86/200
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0734 - accuracy: 0.9679 - val_loss: 1.0707 - val_accuracy: 0.8515
# Epoch 87/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.0752 - accuracy: 0.9679 - val_loss: 1.2172 - val_accuracy: 0.8533
# Epoch 88/200
# 51/51 [==============================] - 4s 69ms/step - loss: 0.0833 - accuracy: 0.9673 - val_loss: 1.1245 - val_accuracy: 0.8462
# Epoch 89/200
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0778 - accuracy: 0.9661 - val_loss: 1.1323 - val_accuracy: 0.8587
# Epoch 90/200
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0749 - accuracy: 0.9692 - val_loss: 1.2194 - val_accuracy: 0.8462
# Epoch 91/200
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0795 - accuracy: 0.9662 - val_loss: 1.1182 - val_accuracy: 0.8605
# Epoch 92/200
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0683 - accuracy: 0.9720 - val_loss: 1.1590 - val_accuracy: 0.8640
# Epoch 93/200
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0711 - accuracy: 0.9700 - val_loss: 1.2220 - val_accuracy: 0.8515
# Epoch 94/200
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0741 - accuracy: 0.9690 - val_loss: 1.2520 - val_accuracy: 0.8479
# Epoch 95/200
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0799 - accuracy: 0.9662 - val_loss: 1.2651 - val_accuracy: 0.8354
# Epoch 96/200
# 51/51 [==============================] - 4s 69ms/step - loss: 0.0772 - accuracy: 0.9687 - val_loss: 1.2412 - val_accuracy: 0.8408
# Epoch 97/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.0727 - accuracy: 0.9701 - val_loss: 1.2904 - val_accuracy: 0.8390
# Epoch 98/200
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0739 - accuracy: 0.9689 - val_loss: 1.2401 - val_accuracy: 0.8515
# Epoch 99/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.0700 - accuracy: 0.9701 - val_loss: 1.1813 - val_accuracy: 0.8551
# Epoch 100/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.0702 - accuracy: 0.9723 - val_loss: 1.2627 - val_accuracy: 0.8515
# Epoch 101/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.0630 - accuracy: 0.9717 - val_loss: 1.1796 - val_accuracy: 0.8640
# Epoch 102/200
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0638 - accuracy: 0.9732 - val_loss: 1.2253 - val_accuracy: 0.8515
# Epoch 103/200
# 51/51 [==============================] - 3s 69ms/step - loss: 0.0609 - accuracy: 0.9742 - val_loss: 1.2695 - val_accuracy: 0.8408
# Epoch 104/200
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0619 - accuracy: 0.9742 - val_loss: 1.2083 - val_accuracy: 0.8462
# Epoch 105/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.0572 - accuracy: 0.9771 - val_loss: 1.3161 - val_accuracy: 0.8462
# Epoch 106/200
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0649 - accuracy: 0.9707 - val_loss: 1.2807 - val_accuracy: 0.8444
# Epoch 107/200
# 51/51 [==============================] - 3s 68ms/step - loss: 0.0651 - accuracy: 0.9717 - val_loss: 1.2649 - val_accuracy: 0.8479
# Epoch 108/200
# 51/51 [==============================] - 4s 70ms/step - loss: 0.0606 - accuracy: 0.9731 - val_loss: 1.2668 - val_accuracy: 0.8462
# Epoch 109/200
# 51/51 [==============================] - 4s 69ms/step - loss: 0.0728 - accuracy: 0.9709 - val_loss: 1.2876 - val_accuracy: 0.8444
# Epoch 110/200
# 51/51 [==============================] - 4s 69ms/step - loss: 0.0666 - accuracy: 0.9712 - val_loss: 1.2132 - val_accuracy: 0.8569
# Epoch 111/200
# 51/51 [==============================] - 4s 69ms/step - loss: 0.0683 - accuracy: 0.9706 - val_loss: 1.2404 - val_accuracy: 0.8426
# Epoch 112/200
# 51/51 [==============================] - 4s 69ms/step - loss: 0.
# Epoch 173/200
# 51/51 [==============================] - 7s 140ms/step - loss: 0.0526 - accuracy: 0.9787 - val_loss: 1.4824 - val_accuracy: 0.8444
# Epoch 174/200
# 51/51 [==============================] - 5s 105ms/step - loss: 0.0580 - accuracy: 0.9742 - val_loss: 1.4468 - val_accuracy: 0.8551
# Epoch 175/200
# 51/51 [==============================] - 7s 142ms/step - loss: 0.0514 - accuracy: 0.9788 - val_loss: 1.5576 - val_accuracy: 0.8497
# Epoch 176/200
# 51/51 [==============================] - 5s 89ms/step - loss: 0.0464 - accuracy: 0.9799 - val_loss: 1.5838 - val_accuracy: 0.8569
# Epoch 177/200
# 51/51 [==============================] - 6s 124ms/step - loss: 0.0554 - accuracy: 0.9770 - val_loss: 1.3405 - val_accuracy: 0.8354
# Epoch 178/200
# 51/51 [==============================] - 4s 84ms/step - loss: 0.0617 - accuracy: 0.9763 - val_loss: 1.3722 - val_accuracy: 0.8444
# Epoch 179/200
# 51/51 [==============================] - 4s 80ms/step - loss: 0.0492 - accuracy: 0.9787 - val_loss: 1.4811 - val_accuracy: 0.8497
# Epoch 180/200
# 51/51 [==============================] - 4s 82ms/step - loss: 0.0460 - accuracy: 0.9809 - val_loss: 1.4393 - val_accuracy: 0.8605
# Epoch 181/200
# 51/51 [==============================] - 4s 79ms/step - loss: 0.0518 - accuracy: 0.9796 - val_loss: 1.4451 - val_accuracy: 0.8551
# Epoch 182/200
# 51/51 [==============================] - 4s 80ms/step - loss: 0.0434 - accuracy: 0.9813 - val_loss: 1.4323 - val_accuracy: 0.8533
# Epoch 183/200
# 51/51 [==============================] - 4s 82ms/step - loss: 0.0506 - accuracy: 0.9767 - val_loss: 1.4162 - val_accuracy: 0.8497
# Epoch 184/200
# 51/51 [==============================] - 4s 81ms/step - loss: 0.0569 - accuracy: 0.9777 - val_loss: 1.3534 - val_accuracy: 0.8515
# Epoch 185/200
# 51/51 [==============================] - 4s 84ms/step - loss: 0.0438 - accuracy: 0.9810 - val_loss: 1.4055 - val_accuracy: 0.8623
# Epoch 186/200
# 51/51 [==============================] - 4s 88ms/step - loss: 0.0435 - accuracy: 0.9809 - val_loss: 1.3653 - val_accuracy: 0.8372
# Epoch 187/200
# 51/51 [==============================] - 4s 84ms/step - loss: 0.0524 - accuracy: 0.9777 - val_loss: 1.3650 - val_accuracy: 0.8569
# Epoch 188/200
# 51/51 [==============================] - 5s 92ms/step - loss: 0.0489 - accuracy: 0.9787 - val_loss: 1.4242 - val_accuracy: 0.8587
# Epoch 189/200
# 51/51 [==============================] - 4s 80ms/step - loss: 0.0421 - accuracy: 0.9829 - val_loss: 1.5275 - val_accuracy: 0.8623
# Epoch 190/200
# 51/51 [==============================] - 4s 88ms/step - loss: 0.0390 - accuracy: 0.9830 - val_loss: 1.5224 - val_accuracy: 0.8605
# Epoch 191/200
# 51/51 [==============================] - 4s 80ms/step - loss: 0.0433 - accuracy: 0.9827 - val_loss: 1.4376 - val_accuracy: 0.8479
# Epoch 192/200
# 51/51 [==============================] - 5s 93ms/step - loss: 0.0466 - accuracy: 0.9805 - val_loss: 1.6027 - val_accuracy: 0.8318
# Epoch 193/200
# 51/51 [==============================] - 4s 82ms/step - loss: 0.0442 - accuracy: 0.9809 - val_loss: 1.6284 - val_accuracy: 0.8444
# Epoch 194/200
# 51/51 [==============================] - 5s 89ms/step - loss: 0.0475 - accuracy: 0.9809 - val_loss: 1.4434 - val_accuracy: 0.8497
# Epoch 195/200
# 51/51 [==============================] - 4s 83ms/step - loss: 0.0504 - accuracy: 0.9799 - val_loss: 1.4051 - val_accuracy: 0.8462
# Epoch 196/200
# 51/51 [==============================] - 5s 92ms/step - loss: 0.0500 - accuracy: 0.9809 - val_loss: 1.5086 - val_accuracy: 0.8605
# Epoch 197/200
# 51/51 [==============================] - 4s 82ms/step - loss: 0.0472 - accuracy: 0.9812 - val_loss: 1.4452 - val_accuracy: 0.8605
# Epoch 198/200
# 51/51 [==============================] - 4s 82ms/step - loss: 0.0445 - accuracy: 0.9816 - val_loss: 1.4133 - val_accuracy: 0.8605
# Epoch 199/200
# 51/51 [==============================] - 4s 87ms/step - loss: 0.0501 - accuracy: 0.9810 - val_loss: 1.5421 - val_accuracy: 0.8533
# Epoch 200/200
# 51/51 [==============================] - 4s 82ms/step - loss: 0.0464 - accuracy: 0.9826 - val_loss: 1.6152 - val_accuracy: 0.8515
# The training of the "CNN_Chandelle" model took 0:15:16.604836.

# %% [markdown]
# ### C.6 - Loading the best model

# %%
best_model = helpers.ckpts.load_best_model(models_folder=MODELS_FOLDER, base_name=ckpt_name_base)

# %% [markdown]
# ## D - Evaluating the model
# ### D.1 - Accuracy and loss

# %%
helpers.perfs.print_model_metrics(model=best_model, x_train=x_train, y_train=y_train, x_test=x_test, y_test=y_test)
# Out:
# Model metrics:
# Training > loss=0.125 | accuracy=97.079
# Testing > loss=0.598 | accuracy=83.801

# %% [markdown]
# As with the ANN, the loss value between the training and test sets is almost the same. Our model neither over-fits nor under-fits the dataset. But its accuracy is much better than our previous model. Getting an accuracy of almost 90% on the test set is a very good result.

# %%
helpers.perfs.plot_loss_curve(history=training_cnn_chandelle.history)
helpers.perfs.plot_accuracy_curve(history=training_cnn_chandelle.history)

# %% [markdown]
# These two graphs look better than with the ANN. We can see that the validation loss increases around the 60th epoch, our best model was taken at the 52nd epoch. It does not have the best accuracy (98.8 on the training set, 93.2 on the test set), but its loss value is very close to the lowest recorded.

# %% [markdown]
# ### D.2 - Confusion matrix

# %%
helpers.perfs.plot_confusion_matrix(model=best_model, x_test=x_test, y_test=y_test, le=label_encoder, classes=CLASSES)
# Out:
#               Class Accuracy
# 0   air_conditioner  89.25 %
# 1          car_horn  85.98 %
# 2  children_playing  65.28 %
# 3          dog_bark  81.72 %
# 4          drilling  86.32 %
# 5     engine_idling  86.92 %
# 6          gun_shot  93.15 %
# 7        jackhammer   89.9 %
# 8             siren  87.27 %
# 9      street_music  78.17 %

# %% [markdown]
# We can easily see the diagonal from top-left corner to the bottom-right corner, which means that our model is not very confused. We notice a lower score for the `car_horn` and `gun_shot` classes, but these classes have almost 50% of data compared to the other classes.
#
# There is some confusion between classes of sounds that may seem similar: `engine_idling` and `air_conditioner`. But there is also confusion between classes that seem quite different. The class `children_playing` is most often confused with `dog_bark` and `street_music`.
#
# ### D.3 - Classification report

# %%
helpers.perfs.print_classification_report(model=best_model, x_test=x_test, y_test=y_test, le=label_encoder, classes=CLASSES)
# Out:
#                   precision    recall  f1-score   support
#
#  air_conditioner       0.86      0.89      0.88       214
#         car_horn       0.97      0.86      0.91       107
# children_playing       0.70      0.65      0.67       193
#         dog_bark       0.77      0.82      0.79       186
#         drilling       0.82      0.86      0.84       190
#    engine_idling       0.81      0.87      0.84       214
#         gun_shot       0.94      0.93      0.94        73
#       jackhammer       0.92      0.90      0.91       208
#            siren       0.88      0.87      0.88       165
#     street_music       0.85      0.78      0.81       197
#
#         accuracy                           0.84      1747
#        macro avg       0.85      0.84      0.85      1747
#     weighted avg       0.84      0.84      0.84      1747

# %% [markdown]
# ## E - Conclusion of the CNN model
# **TODO**
