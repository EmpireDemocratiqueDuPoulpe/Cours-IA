# %% [markdown]
# ## School project - 5DEEP
# The following notebook has been created for a school project on audio classification. The subject and the questions are available in the appendix.
#
# The group members who participated in this project are:
# - BEZIN Théo
# - LAMINE AMIMI
# - LECOMTE Alexis
# - PAWLOWSKI Maxence
#
# ### Main index
# 1. Data analysis
# 2. Data preprocessing
# 3. Basic ANN model
# 4. **The CNN model (you are here)**
# 5. Testing our best model

# %% [markdown]
# # 4 - The CNN model
# Our previous model showed very poor performance on the Mel spectrogram. For this notebook, we will define a Convolutional Neural Network (CNN) that takes a three-dimensional array as input. The extra dimensions will allow the model to train better by extracting more features from the spectrograms.
#
# ### Index
# <ol type="A">
#   <li>Notebook initialization</li>
#   <li>Data preparation</li>
#   <li>Second model: Convolutional Neural Network (CNN)</li>
#   <li>Evaluating the model</li>
#   <li>Conclusion of the CNN model</li>
# </ol>

# %% [markdown]
# ## A - Notebook initialization
# ### A.1 - Imports

# %%
# OS and filesystem
import os
import sys
from pathlib import Path
from timeit import default_timer as timer
from datetime import timedelta

# Math
import numpy

# Data
from matplotlib import pyplot

# Model processing
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow import keras

# Console output
from colorama import Style

# Local files
sys.path.append(os.path.join(os.pardir, os.pardir))
import helpers

# %% [markdown]
# ### A.2 - Package initialization

# %%
pyplot.style.use("ggplot")  # Set the matplotlib style
keras.backend.set_image_data_format("channels_last")  # Define the last value of the model input shape as the color channel

# %% [markdown]
# ### A.3 - Constants

# %%
# Filesystem paths
PARENT_FOLDER = Path.cwd()
DATA_FOLDER = (PARENT_FOLDER / ".." / ".." / "data").resolve()
URBAN_DATASET_FOLDER = DATA_FOLDER / "UrbanSound8K"
MODELS_FOLDER = (PARENT_FOLDER / ".." / ".." / "models").resolve()
TEMP_FOLDER = (PARENT_FOLDER / ".." / ".." / "temp").resolve()

# Dataset
CLASSES = ["air_conditioner", "car_horn", "children_playing", "dog_bark", "drilling", "engine_idling", "gun_shot", "jackhammer", "siren", "street_music"]
N_MELS = 128

# Misc.
RANDOM_STATE = 2077

# %% [markdown]
# ### A.4 - Dataset loading

# %%
features_x = numpy.load(file=(str(DATA_FOLDER / "x-mel-spectrograms_13-02-23_14-44.npy")))
features_y = numpy.load(file=(str(DATA_FOLDER / "y-mel-spectrograms_13-02-23_14-44.npy")))

# %% [markdown]
# ## B - Data preparation
# ### B.1 - Label encoding
# We will use the same encoding method as for the ANN model, a one-hot encoding.

# %%
label_encoder = LabelEncoder()
features_y = keras.utils.to_categorical(y=label_encoder.fit_transform(features_y), num_classes=len(CLASSES))

# %% [markdown]
# ### B.2 - Dataset splitting

# %%
x_train, x_test, y_train, y_test = train_test_split(features_x, features_y, test_size=0.2, random_state=RANDOM_STATE)

print(f"{Style.BRIGHT}Train set >{Style.RESET_ALL} rows: (x={len(x_train)}, y={len(y_train)}) | shape: (x={x_train.shape}, y={y_train.shape})")
print(f"{Style.BRIGHT}Test set >{Style.RESET_ALL} rows: (x={len(x_test)}, y={len(y_test)}) | shape: (x={x_test.shape}, y={y_test.shape})")
# Out:
# Train set > rows: (x=6985, y=6985) | shape: (x=(6985, 128, 173), y=(6985, 10))
# Test set > rows: (x=1747, y=1747) | shape: (x=(1747, 128, 173), y=(1747, 10))

# %% [markdown]
# The input layer of the CNN model takes a 4+D tensor with the form $batchShape, (rows, cols, channels)$. We need to reshape our dataset to match the second part in parentheses.

# %%
num_columns = 173
num_channels = 1

x_train = x_train.reshape(x_train.shape[0], N_MELS, num_columns, num_channels)
x_test = x_test.reshape(x_test.shape[0], N_MELS, num_columns, num_channels)

# %% [markdown]
# ## C - Second model: Convolutional Neural Network (CNN)
# ### C.1 - Model architecture
# We will use the same model API as for the ANN, the [Sequential](https://keras.io/guides/sequential_model/) API.
#
# 1. The first three groups start with a [Conv2D](https://keras.io/api/layers/convolution_layers/convolution2d/) layer. It creates a convolution kernel that is convolved with the layer input to produce a tensor of outputs. The input shape of this layer is $batchShape, (rows, cols, channels)$ and the output shape is $batchShape, (newRows, newCols, filters)$. The next layer is a [MaxPooling2D](https://keras.io/api/layers/pooling_layers/max_pooling2d/) layer that down-samples the input along its spatial dimensions (height and width). The final layer of those groups is the [activation function](https://keras.io/api/layers/core_layers/activation/).
# 2. The fourth group begins with a [Flatten](https://keras.io/api/layers/reshaping_layers/flatten/) layer used, as the name suggests, to flatten the input. This group ends with the [Dropout](https://keras.io/api/layers/regularization_layers/dropout/) layer which "removes" input values by setting them to 0. This layer prevents over-fitting.
# 3. The last two groups are classic [Dense](https://keras.io/api/layers/core_layers/dense/) layers with a [softmax](https://keras.io/api/layers/activations/#softmax-function) activation function for the final output.
#
# ### C.2 - Model definition

# %%
# Model definition
model_cnn_milva = keras.models.Sequential(name="CNN_Milva", layers=[
    # First convolution block
    keras.layers.Conv2D(filters=32, kernel_size=(3, 3),padding='same', strides=(1, 1), input_shape=(N_MELS, num_columns, num_channels)),
    keras.layers.Activation("relu"),

    # Second convolution block
    keras.layers.Conv2D(filters=64, kernel_size=(3, 3)),
    keras.layers.Activation("relu"),
    keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),
    keras.layers.Dropout(rate=0.5),


    # Third convolution block
    keras.layers.Conv2D(filters=64, kernel_size=(3, 3), strides=(1, 1), padding="same"),
    keras.layers.Activation("relu"),
    keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),

    # Four convolution block
    keras.layers.Conv2D(filters=64, kernel_size=(3, 3), strides=(1, 1), padding="same"),
    keras.layers.MaxPooling2D(pool_size=(4, 4), strides=(4, 4)),

    # Flatten and dropout
    keras.layers.Flatten(),
    keras.layers.Dropout(rate=0.5),

    # First dense block
    keras.layers.Dense(64, activation="relu"),
    keras.layers.Dropout(rate=0.5),

    # Second dense block. Using softmax to reduce to output to 1
    keras.layers.Dense(len(CLASSES), activation="softmax")
])

# Model summary and plot
model_cnn_milva.summary()
keras.utils.plot_model(
    model_cnn_milva,
    show_shapes=True, show_dtype=True, show_layer_names=True, show_layer_activations=True,
    rankdir="TB", dpi=72,
    to_file=(TEMP_FOLDER / "model_cnn_milva.png")
)
# Out:
# 2023-02-15 15:19:06.266327: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-15 15:19:06.474408: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-15 15:19:06.474924: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-15 15:19:06.585778: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-15 15:19:06.588869: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-15 15:19:06.589247: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-15 15:19:06.589499: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-15 15:19:08.593742: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-15 15:19:08.595516: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-15 15:19:08.595560: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1700] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-02-15 15:19:08.600797: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-15 15:19:08.603999: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6564 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1
# Model: "CNN_Milva"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 173, 32)      320
#
#  activation (Activation)     (None, 128, 173, 32)      0
#
#  conv2d_1 (Conv2D)           (None, 126, 171, 64)      18496
#
#  activation_1 (Activation)   (None, 126, 171, 64)      0
#
#  max_pooling2d (MaxPooling2D  (None, 63, 85, 64)       0
#  )
#
#  dropout (Dropout)           (None, 63, 85, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 63, 85, 64)        36928
#
#  activation_2 (Activation)   (None, 63, 85, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 31, 42, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 31, 42, 64)        36928
#
#  max_pooling2d_2 (MaxPooling  (None, 7, 10, 64)        0
#  2D)
#
#  flatten (Flatten)           (None, 4480)              0
#
#  dropout_1 (Dropout)         (None, 4480)              0
#
#  dense (Dense)               (None, 64)                286784
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 380,106
# Trainable params: 380,106
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### C.3 - Model optimizer and loss function

# %%
adam_optimizer = keras.optimizers.Adam(learning_rate=0.005)
model_cnn_milva.compile(loss="categorical_crossentropy", optimizer=adam_optimizer, metrics=["accuracy"])

# %% [markdown]
# ### C.4 - Model callbacks

# %%
# Model checkpoint to save the model to the disk
ckpt_name_base = "2_model-cnn-lamine-ckpt"

checkpoint_callback = keras.callbacks.ModelCheckpoint(
    filepath=str(MODELS_FOLDER / f"{ckpt_name_base}_e-{{epoch:02d}}_vloss-{{val_loss:.2f}}.hdf5"),
    monitor="val_loss",
    save_best_only=True,
    verbose=0
)

# %% [markdown]
# ### C.5 - Model training

# %%
batch_size = 128
epochs = 200

start_time = timer()
training_cnn_milva = model_cnn_milva.fit(x=x_train, y=y_train, validation_split=0.080, batch_size=batch_size, epochs=epochs, callbacks=[checkpoint_callback], verbose=1)
print(f"The training of the \"{model_cnn_milva.name}\" model took {timedelta(seconds=(timer() - start_time))}.")
# Out:
# 2023-02-15 15:20:44.785197: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 569189376 exceeds 10% of free system memory.
# 2023-02-15 15:20:46.094043: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 569189376 exceeds 10% of free system memory.
# Epoch 1/200
# 2023-02-15 15:20:49.383810: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inCNN_Milva/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-02-15 15:20:50.804701: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8100
# 2023-02-15 15:20:53.995408: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-02-15 15:21:02.384519: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7f705c00f130 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-02-15 15:21:02.384568: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce GTX 1080, Compute Capability 6.1
# 2023-02-15 15:21:05.042261: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-02-15 15:21:17.468880: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-02-15 15:21:17.819928: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2023-02-15 15:21:20.276407: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 5.05GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-02-15 15:21:20.504878: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 6.72GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 51/51 [==============================] - 52s 379ms/step - loss: 2.0602 - accuracy: 0.2577 - val_loss: 1.8549 - val_accuracy: 0.3453
# Epoch 2/200
# 51/51 [==============================] - 17s 333ms/step - loss: 1.5796 - accuracy: 0.4497 - val_loss: 1.5025 - val_accuracy: 0.4508
# Epoch 3/200
# 51/51 [==============================] - 17s 333ms/step - loss: 1.2762 - accuracy: 0.5521 - val_loss: 1.0918 - val_accuracy: 0.6190
# Epoch 4/200
# 51/51 [==============================] - 17s 325ms/step - loss: 1.1336 - accuracy: 0.5996 - val_loss: 0.9357 - val_accuracy: 0.6995
# Epoch 5/200
# 51/51 [==============================] - 17s 326ms/step - loss: 0.9998 - accuracy: 0.6539 - val_loss: 1.2213 - val_accuracy: 0.5957
# Epoch 6/200
# 51/51 [==============================] - 18s 346ms/step - loss: 0.9497 - accuracy: 0.6776 - val_loss: 0.8570 - val_accuracy: 0.7066
# Epoch 200/200
# 51/51 [==============================] - 20s 401ms/step - loss: 0.3737 - accuracy: 0.8850 - val_loss: 0.8570 - val_accuracy: 0.8229
# The training of the "CNN_Milva" model took 1:00:09.716533.

# %% [markdown]
# ### C.6 - Loading the best model

# %%
best_model = helpers.ckpts.load_best_model(models_folder=MODELS_FOLDER, base_name=ckpt_name_base)

# %% [markdown]
# ## D - Evaluating the model
# ### D.1 - Accuracy and loss

# %%
helpers.perfs.print_model_metrics(model=best_model, x_train=x_train, y_train=y_train, x_test=x_test, y_test=y_test)
# Out:
# 2023-02-15 16:26:55.378569: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 618703360 exceeds 10% of free system memory.
# 2023-02-15 16:27:08.938046: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 618703360 exceeds 10% of free system memory.
# Model metrics:
# Training > loss=0.158 | accuracy=95.805
# Testing > loss=0.478 | accuracy=86.949

# %% [markdown]
# As with the ANN, the loss value between the training and test sets is almost the same. Our model neither over-fits nor under-fits the dataset. But its accuracy is much better than our previous model. Getting an accuracy of almost 90% on the test set is a very good result.

# %%
helpers.perfs.plot_loss_curve(history=training_cnn_milva.history)
helpers.perfs.plot_accuracy_curve(history=training_cnn_milva.history)

# %% [markdown]
# These two graphs look better than with the ANN. We can see that the validation loss increases around the 60th epoch, our best model was taken at the 52nd epoch. It does not have the best accuracy (98.8 on the training set, 93.2 on the test set), but its loss value is very close to the lowest recorded.

# %% [markdown]
# ### D.2 - Confusion matrix

# %%
helpers.perfs.plot_confusion_matrix(model=best_model, x_test=x_test, y_test=y_test, le=label_encoder, classes=CLASSES)
# Out:
#               Class Accuracy
# 0   air_conditioner  86.45 %
# 1          car_horn  86.92 %
# 2  children_playing  76.68 %
# 3          dog_bark  86.02 %
# 4          drilling  82.11 %
# 5     engine_idling  89.72 %
# 6          gun_shot  98.63 %
# 7        jackhammer  96.15 %
# 8             siren  89.09 %
# 9      street_music  84.26 %

# %% [markdown]
# We can easily see the diagonal from top-left corner to the bottom-right corner, which means that our model is not very confused. We notice a lower score for the `car_horn` and `gun_shot` classes, but these classes have almost 50% of data compared to the other classes.
#
# There is some confusion between classes of sounds that may seem similar: `engine_idling` and `air_conditioner`. But there is also confusion between classes that seem quite different. The class `children_playing` is most often confused with `dog_bark` and `street_music`.
#
# ### D.3 - Classification report

# %%
helpers.perfs.print_classification_report(model=best_model, x_test=x_test, y_test=y_test, le=label_encoder, classes=CLASSES)
# Out:
#                   precision    recall  f1-score   support
#
#  air_conditioner       0.86      0.86      0.86       214
#         car_horn       0.94      0.87      0.90       107
# children_playing       0.86      0.77      0.81       193
#         dog_bark       0.83      0.86      0.85       186
#         drilling       0.87      0.82      0.84       190
#    engine_idling       0.82      0.90      0.86       214
#         gun_shot       0.88      0.99      0.93        73
#       jackhammer       0.90      0.96      0.93       208
#            siren       0.95      0.89      0.92       165
#     street_music       0.84      0.84      0.84       197
#
#         accuracy                           0.87      1747
#        macro avg       0.88      0.88      0.87      1747
#     weighted avg       0.87      0.87      0.87      1747

# %% [markdown]
# ## E - Conclusion of the CNN model
# **TODO**
